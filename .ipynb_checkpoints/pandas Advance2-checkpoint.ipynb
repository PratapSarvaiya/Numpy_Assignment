# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv",header=None)

# %%
df.head()
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
# 4            4         1       1
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                              Heikkinen, Miss Laina  female   26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
#
#       7                 8        9      10        11
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S
# 4      0            113803     53.1   C123         S

# %%
df.tail()
# Out:
#       0  1  2                                        3       4    5  6  7   \
# 887  887  0  2                    Montvila, Rev. Juozas    male   27  0  0
# 888  888  1  1              Graham, Miss Margaret Edith  female   19  0  0
# 889  889  0  3  Johnston, Miss Catherine Helen "Carrie"  female  NaN  1  2
# 890  890  1  1                    Behr, Mr. Karl Howell    male   26  0  0
# 891  891  0  3                      Dooley, Mr. Patrick    male   32  0  0
#
#              8      9     10 11
# 887      211536     13   NaN  S
# 888      112053     30   B42  S
# 889  W./C. 6607  23.45   NaN  S
# 890      111369     30  C148  C
# 891      370376   7.75   NaN  Q

# %%
df.shape
# Out:
# (892, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       892 non-null    object
#  1   1       892 non-null    object
#  2   2       892 non-null    object
#  3   3       892 non-null    object
#  4   4       892 non-null    object
#  5   5       715 non-null    object
#  6   6       892 non-null    object
#  7   7       892 non-null    object
#  8   8       892 non-null    object
#  9   9       892 non-null    object
#  10  10      205 non-null    object
#  11  11      890 non-null    object
# dtypes: object(12)
# memory usage: 83.8+ KB

# %%
df.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# 11    object
# dtype: object

# %%
df[0:100]
# Out:
#              0         1       2   \
# 0   PassengerId  Survived  Pclass
# 1             1         0       3
# 2             2         1       1
# 3             3         1       3
# 4             4         1       1
# ..          ...       ...     ...
# 95           95         0       3
# 96           96         0       3
# 97           97         0       1
# 98           98         1       1
# 99           99         1       2
#
#                                                    3       4    5      6   \
# 0                                                Name     Sex  Age  SibSp
# 1                             Braund, Mr. Owen Harris    male   22      1
# 2   Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss Laina  female   26      0
# 4        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                ...     ...  ...    ...
# ...

# %%
df[0:100:2]
# Out:
#              0         1       2   \
# 0   PassengerId  Survived  Pclass
# 2             2         1       1
# 4             4         1       1
# 6             6         0       3
# 8             8         0       3
# 10           10         1       2
# 12           12         1       1
# 14           14         0       3
# 16           16         1       2
# 18           18         1       2
# 20           20         1       3
# 22           22         1       2
# 24           24         1       1
# 26           26         1       3
# 28           28         0       1
# 30           30         0       3
# 32           32         1       1
# 34           34         0       2
# 36           36         0       1
# 38           38         0       3
# 40           40         1       3
# 42           42         0       2
# 44           44         1       2
# 46           46         0       3
# 48           48         1       3
# 50           50         0       3
# ...

# %%
df[0:100:5]
# Out:
#              0         1       2   \
# 0   PassengerId  Survived  Pclass
# 5             5         0       3
# 10           10         1       2
# 15           15         0       3
# 20           20         1       3
# 25           25         0       3
# 30           30         0       3
# 35           35         0       1
# 40           40         1       3
# 45           45         1       3
# 50           50         0       3
# 55           55         0       1
# 60           60         0       3
# 65           65         0       1
# 70           70         0       3
# 75           75         1       3
# 80           80         1       3
# 85           85         1       2
# 90           90         0       3
# 95           95         0       3
#
#                                                3       4    5      6      7   \
# 0                                            Name     Sex  Age  SibSp  Parch
# ...

# %%
# Access rows and columns of a dataframe >> implicit/integer/internal indexing,explicit or named indexing

# %%
#iloc   >> implicit/integer/internal

df.iloc[0:3]   # start from 0 and go till 2
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#       7          8        9      10        11
# 0  Parch     Ticket     Fare  Cabin  Embarked
# 1      0  A/5 21171     7.25    NaN         S
# 2      0   PC 17599  71.2833    C85         C

# %%
# loc  >> explicit or named indexing

df.loc[0:3] # loc used for named indexing,iloc is used for integer indexes
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                              Heikkinen, Miss Laina  female   26      0
#
#       7                 8        9      10        11
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S

# %%
df.iloc[0:3]
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#       7          8        9      10        11
# 0  Parch     Ticket     Fare  Cabin  Embarked
# 1      0  A/5 21171     7.25    NaN         S
# 2      0   PC 17599  71.2833    C85         C

# %%
df.iloc[0:2,["Name","Sex"]]  # it will throw an error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.iloc[0:2,["Name","Sex"]]  # it will throw an error
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
# ...

# %%
df
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                                Heikkinen, Miss Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[0:2,["Name","Sex"]]
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                              Heikkinen, Miss Laina  female

# %%
df.iloc[0:2,3:5]  # because of integer number is allowed
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female

# %%
list(df["Name"][2:5])
# Out:
# ['Heikkinen, Miss Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
s = pd.Series(list(df["Name"][2:5]),index = ['a','b','c'])
s
# Out:
# a                           Heikkinen, Miss Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
import pandas as pd
s1 = pd.Series(list(df["Name"][5:8]))
s1
# Out:
# 0                 Moran, Mr. James
# 1          McCarthy, Mr. Timothy J
# 2    Palsson, Master Gosta Leonard
# dtype: object

# %%
"pw"+" "+"skills"
# Out:
# 'pw skills'

# %%
# Series with different indexes and dataframe can not be concatenated using "+"s

s + s1
# Out:
# a    NaN
# b    NaN
# c    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# dtype: object

# %%
# if you keep indexes same, then for series concatenation can happen

s1 = pd.Series(list(df["Name"][5:8]),index = ['a','b','c'])
s1
# Out:
# a                 Moran, Mr. James
# b          McCarthy, Mr. Timothy J
# c    Palsson, Master Gosta Leonard
# dtype: object

# %%
s
# Out:
# a                           Heikkinen, Miss Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s + s1
# Out:
# a                Heikkinen, Miss LainaMoran, Mr. James
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...
# c    Allen, Mr. William HenryPalsson, Master Gosta ...
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("PassengerId",axis = 1)  # remove column particular column name and axis=1,axis=0 means drop from row,inplace=True means modify the original dataframe
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                              Heikkinen, Miss Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                        Graham, Miss Margaret Edith
# 888         0       3            Johnston, Miss Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(1, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                           Heikkinen, Miss Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# ...

# %%
df.reset_index(drop=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              3         1       3
# 2              4         1       1
# 3              5         0       3
# 4              6         0       3
# ..           ...       ...     ...
# 885          887         0       2
# 886          888         1       1
# 887          889         0       3
# 888          890         1       1
# 889          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 1                           Heikkinen, Miss Laina  female  26.0      0      0
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 3                        Allen, Mr. William Henry    male  35.0      0      0
# 4                                Moran, Mr. James    male   NaN      0      0
# ...

# %%
# set a new index
df.set_index('Name', inplace = True)

# %%
df.set_index('Name',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6832\846678178.py in ?()
# ----> 1 df.set_index('Name',inplace = True)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Name'] are in the columns"

# %%
df.loc['Braund, Mr. Owen Harris	']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Braund, Mr. Owen Harris\t'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ...

# %%
df[0:100:2]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Moran, Mr. James                                              6         0
# Palsson, Master Gosta Leonard                                 8         0
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# Bonnell, Miss Elizabeth                                      12         1
# Andersson, Mr. Anders Johan                                  14         0
# Hewlett, Mrs. (Mary D Kingcome)                              16         1
# Williams, Mr. Charles Eugene                                 18         1
# Masselmani, Mrs. Fatima                                      20         1
# Beesley, Mr. Lawrence                                        22         1
# Sloper, Mr. William Thompson                                 24         1
# ...

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[0:100:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# ...

# %%
d = {'key1':[2,3,4],   # dictionary to dataframe
    'key2':[5,6,7],
    'key3':[8,9,10]}

# %%
d
# Out:
# {'key1': [2, 3, 4], 'key2': [5, 6, 7], 'key3': [8, 9, 10]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     5     8
# 1     3     6     9
# 2     4     7    10

# %%
d = {'key1':(2,3,4),   # tuple to dataframe
    'key2':(5,6,7),
    'key3':(8,9,10)}

# %%
d
# Out:
# {'key1': (2, 3, 4), 'key2': (5, 6, 7), 'key3': (8, 9, 10)}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     5     8
# 1     3     6     9
# 2     4     7    10

# %%
df1 = pd.read_csv("taxonomy.csv")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.describe()
# Out:
#        taxonomy_id          name  parent_id       parent_name
# count          290           290        279               279
# unique         290           183         60                50
# top            101  Nursing Home  106-06-07  Health Education
# freq             1             4         11                15

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %%
df1.isnull().sum()
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.dropna()  # remove null values from rows
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis = 1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1[['name']].dropna(axis = 1) # for one column and double square bracket means data frame
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
# imputation of missing values >> replacing missing values with some values
# numeric data>> mean and median>>outlier(abnormal) value treatment is done,then use mean
# categorical data >> mode
#input missing with some constant, i.e-0

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna("somevalue")    # nan value to replace somevalue
# Out:
#     taxonomy_id                          name  parent_id           parent_name
# 0           101                     Emergency  somevalue             somevalue
# 1        101-01             Disaster Response        101             Emergency
# 2        101-02                Emergency Cash        101             Emergency
# 3     101-02-01             Help Pay for Food     101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare     101-02        Emergency Cash
# ..          ...                           ...        ...                   ...
# 285   111-01-07              Workplace Rights     111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation        111                 Legal
# 287      111-03                        Notary        111                 Legal
# 288      111-04                Representation        111                 Legal
# 289      111-05  Translation & Interpretation        111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna(0)  # replace missing value with 0
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency         0                     0
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
data1 = {
    'A':[1,2,None,4,5,None,7,8,9,10],
    'B':[None,11,12,13,None,15,16,None,18,19]
}
df2 = pd.DataFrame(data1)

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2['A'].mean()
# Out:
# 5.75

# %%
df2['A'].fillna(df2['A'].mean())  # replace missing value with mean
# Out:
# 0     1.00
# 1     2.00
# 2     5.75
# 3     4.00
# 4     5.00
# 5     5.75
# 6     7.00
# 7     8.00
# 8     9.00
# 9    10.00
# Name: A, dtype: float64

# %%
df2['A'].median()
# Out:
# 6.0

# %%
df2['A'].fillna(df2['A'].median())
# Out:
# 0     1.0
# 1     2.0
# 2     6.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna("some value")
# Out:
#             A           B
# 0         1.0  some value
# 1         2.0        11.0
# 2  some value        12.0
# 3         4.0        13.0
# 4         5.0  some value
# 5  some value        15.0
# 6         7.0        16.0
# 7         8.0  some value
# 8         9.0        18.0
# 9        10.0        19.0

# %%
df2.fillna(0)
# Out:
#       A     B
# 0   1.0   0.0
# 1   2.0  11.0
# 2   0.0  12.0
# 3   4.0  13.0
# 4   5.0   0.0
# 5   0.0  15.0
# 6   7.0  16.0
# 7   8.0   0.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(method = "ffill") # forward fill >> start seeing from the bottom of dataframe and fill with the next observed value
# Out:
# C:\Users\Pratap sarvaiya\AppData\Local\Temp\ipykernel_12540\255432943.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method = "ffill") # forward fill
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   2.0  12.0
# 3   4.0  13.0
# 4   5.0  13.0
# 5   5.0  15.0
# 6   7.0  16.0
# 7   8.0  16.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(method="bfill") # Backward fill >> see the dataframe from top and fill with next observed value
# Out:
# C:\Users\Pratap sarvaiya\AppData\Local\Temp\ipykernel_12540\2765026685.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method="bfill") # Backward fill >> see the dataframe from top and fill with next observed value
#       A     B
# 0   1.0  11.0
# 1   2.0  11.0
# 2   4.0  12.0
# 3   4.0  13.0
# 4   5.0  15.0
# 5   7.0  15.0
# 6   7.0  16.0
# 7   8.0  18.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
#checking duplicate rows
df2.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss Laina                                         3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss Margaret Edith                                 888         1
# Johnston, Miss Catherine Helen "Carrie"                     889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df = df.apply(pd.to_numeric, errors='coerce')
mean_values = df.mean()

# %%
mean_values
# Out:
# PassengerId       446.000000
# Survived            0.383838
# Pclass              2.308642
# Sex                      NaN
# Age                29.699118
# SibSp               0.523008
# Parch               0.381594
# Ticket         260318.549168
# Fare               32.204208
# Cabin                    NaN
# Embarked                 NaN
# dtype: float64

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.mean()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# ...

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss Laina                                         3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss Margaret Edith                                 888         1
# Johnston, Miss Catherine Helen "Carrie"                     889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
print(df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex            float64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket         float64
# Fare           float64
# Cabin          float64
# Embarked       float64
# dtype: object

# %%
df.median()
# Out:
# PassengerId       446.0000
# Survived            0.0000
# Pclass              3.0000
# Sex                    NaN
# Age                28.0000
# SibSp               0.0000
# Parch               0.0000
# Ticket         236171.0000
# Fare               14.4542
# Cabin                  NaN
# Embarked               NaN
# dtype: float64

# %%
df.std()  # standard deviation
# Out:
# PassengerId       257.353842
# Survived            0.486592
# Pclass              0.836071
# Sex                      NaN
# Age                14.526497
# SibSp               1.102743
# Parch               0.806057
# Ticket         471609.268688
# Fare               49.693429
# Cabin                    NaN
# Embarked                 NaN
# dtype: float64

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.reset_index(inplace = True)
df
# Out:
#      index                                               Name  PassengerId  \
# 0        0                            Braund, Mr. Owen Harris            1
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 2        2                              Heikkinen, Miss Laina            3
# 3        3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 4        4                           Allen, Mr. William Henry            5
# ..     ...                                                ...          ...
# 886    886                              Montvila, Rev. Juozas          887
# 887    887                        Graham, Miss Margaret Edith          888
# 888    888            Johnston, Miss Catherine Helen "Carrie"          889
# 889    889                              Behr, Mr. Karl Howell          890
# 890    890                                Dooley, Mr. Patrick          891
#
# ...

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                                Heikkinen, Miss Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                        Graham, Miss Margaret Edith          888         1
# 888            Johnston, Miss Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
# Q. what is the average fare paid by the people who survive?

# %%
df[df['Survived'] == 1]['Fare'].mean()
# Out:
# np.float64(48.32828768328446)

# %%
df[df['Survived'] == 0]['Fare'].mean()
# Out:
# np.float64(22.117886885245902)

# %%
# what if I as average age who survived? change Fare to Age
# what if I ask max, min, std avg/fare in one result
# gruopby

# %%
df.groupby('Survived').mean(numeric_only = True)
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          445.665689  1.953079  28.310277  0.472141  0.466276  48.328288

# %% [markdown]
# df.groupby('Survived').sum(numeric_only = True)

# %%
df.groupby('Survived').sum(numeric_only = True)
# Out:
#           PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0              245412    1390  12985.50    304    181  12142.7199
# 1              151972     666   8181.67    161    159  16479.9461

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                           \
#                count        mean         std  min    25%    50%    75%    max
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.0  455.0  675.0  891.0
# 1              341.0  445.665689  251.585069  3.0  256.0  441.0  652.0  890.0
#
#          Pclass            ... Parch        Fare                             \
#           count      mean  ...   75%  max  count       mean        std  min
# Survived                   ...
# 0         549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207  0.0
# 1         341.0  1.953079  ...   1.0  5.0  341.0  48.328288  66.683277  0.0
#
#
#               25%   50%   75%       max
# Survived
# 0          7.8542  10.5  26.0  263.0000
# 1         12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
df[['Survived','Fare']]
# Out:
#                                               Survived     Fare
# Name
# Braund, Mr. Owen Harris                              0   7.2500
# Heikkinen, Miss Laina                                1   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1  53.1000
# Allen, Mr. William Henry                             0   8.0500
# Moran, Mr. James                                     0   8.4583
# ...                                                ...      ...
# Montvila, Rev. Juozas                                0  13.0000
# Graham, Miss Margaret Edith                          1  30.0000
# Johnston, Miss Catherine Helen "Carrie"              0  23.4500
# Behr, Mr. Karl Howell                                1  30.0000
# Dooley, Mr. Patrick                                  0   7.7500
#
# [890 rows x 2 columns]

# %%
import numpy as np
df.groupby(['Survived'])['Fare'].agg([min, 'max', 'mean', 'median', 'count', np.std,'var'])
# Out:
# C:\Users\Pratap sarvaiya\AppData\Local\Temp\ipykernel_6832\2828612075.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(['Survived'])['Fare'].agg([min, 'max', 'mean', 'median', 'count', np.std,'var'])
# C:\Users\Pratap sarvaiya\AppData\Local\Temp\ipykernel_6832\2828612075.py:2: FutureWarning: The provided callable <function std at 0x000002271D596160> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df.groupby(['Survived'])['Fare'].agg([min, 'max', 'mean', 'median', 'count', np.std,'var'])
#           min       max       mean  median  count        std          var
# Survived
# 0         0.0  263.0000  22.117887    10.5    549  31.388207   985.219509
# ...

# %%
# how many passengers servived/ no survived for each sex and pclass

df.groupby(['Sex', 'Pclass'])['Survived'].sum()
# Out:
# Sex     Pclass
# female  1         90
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: Survived, dtype: int64

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame()
# Out:
#                Survived
# Sex    Pclass
# female 1             90
#        2             70
#        3             72
# male   1             45
#        2             17
#        3             47

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame().reset_index()
# Out:
#       Sex  Pclass  Survived
# 0  female       1        90
# 1  female       2        70
# 2  female       3        72
# 3    male       1        45
# 4    male       2        17
# 5    male       3        47

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().unstack()
# Out:
# Pclass   1   2   3
# Sex
# female  90  70  72
# male    45  17  47

# %%
a = df.groupby('Pclass').sum(numeric_only = True)

# %%
a
# Out:
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99703       135  7073.42     89     77  18106.1292
# 2             82056        87  5168.83     74     70   3801.8417
# 3            215625       119  8924.92    302    193   6714.6951

# %%
a.T
# Out:
# Pclass                1           2            3
# PassengerId  99703.0000  82056.0000  215625.0000
# Survived       135.0000     87.0000     119.0000
# Age           7073.4200   5168.8300    8924.9200
# SibSp           89.0000     74.0000     302.0000
# Parch           77.0000     70.0000     193.0000
# Fare         18106.1292   3801.8417    6714.6951

# %%
a.transpose()
# Out:
# Pclass                1           2            3
# PassengerId  99703.0000  82056.0000  215625.0000
# Survived       135.0000     87.0000     119.0000
# Age           7073.4200   5168.8300    8924.9200
# SibSp           89.0000     74.0000     302.0000
# Parch           77.0000     70.0000     193.0000
# Fare         18106.1292   3801.8417    6714.6951

# %%
df.head().T
# Out:
# Name        Braund, Mr. Owen Harris Heikkinen, Miss Laina  \
# PassengerId                       1                     3
# Survived                          0                     1
# Pclass                            3                     3
# Sex                            male                female
# Age                            22.0                  26.0
# SibSp                             1                     0
# Parch                             0                     0
# Ticket                    A/5 21171      STON/O2. 3101282
# Fare                           7.25                 7.925
# Cabin                           NaN                   NaN
# Embarked                          S                     S
#
# Name        Futrelle, Mrs. Jacques Heath (Lily May Peel)  \
# PassengerId                                            4
# Survived                                               1
# Pclass                                                 1
# ...
