# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\pratap sarvaiya\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\pratap sarvaiya\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pratap sarvaiya\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pratap sarvaiya\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pratap sarvaiya\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\pratap sarvaiya\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# DEPRECATION: Loading egg at c:\users\pratap sarvaiya\appdata\local\programs\python\python311\lib\site-packages\openpyxl-3.1.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# why do we need visualisation?  # summarisation of data
# matplotlib, seaborn,plotly,bokeh

# %%
# Matplotlib  >> Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')  # suppress all the warnings

# %%
# line,scatter,bar,histogram,pie chart,box plot,violin plot

# %%
#generate random numbers in numpy
x = np.random.rand(50)

# %%
len(x)
# Out:
# 50

# %%
x = np.random.randn(50)

# %%
x
# Out:
# array([ 1.09613924, -0.4765363 , -0.86341582,  0.27289943,  0.09115414,
#        -1.15189911,  0.37610689,  0.91380801,  0.82033147,  0.86879061,
#         0.87056055, -0.25126344, -1.94897847, -0.20022368, -0.0058547 ,
#        -1.04843917, -0.60710373, -1.6407925 , -1.7254692 ,  1.2854926 ,
#         0.36867979,  0.9296022 ,  1.24811364, -0.89373213,  2.04935297,
#         0.58453276,  0.2548525 , -0.39519457, -0.71307283,  0.40344995,
#         0.26752634,  0.50015998, -0.43423725,  0.25132484, -0.11043933,
#        -1.2643276 , -0.00625845, -0.13905221, -0.12518431,  1.34557346,
#        -0.11292449, -0.27892628,  0.18852643, -1.20976609,  1.11214489,
#        -0.39152937,  0.47756733, -0.10351884,  0.50938799, -1.19131679])

# %%
df = pd.DataFrame(np.random.randn(1000),columns = ['Data'],index = pd.date_range('2024-07-11',periods = 1000))
df
# Out:
#                 Data
# 2024-07-11  1.208276
# 2024-07-12  0.020008
# 2024-07-13  0.109112
# 2024-07-14 -0.733745
# 2024-07-15  1.268814
# ...              ...
# 2027-04-02  0.825742
# 2027-04-03  0.337003
# 2027-04-04  0.299365
# 2027-04-05 -1.208188
# 2027-04-06 -0.425654
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,8))  # most of the values are fluctuating between -2 and 2
# Out:
# <Axes: >

# %%
y = np.random.rand(50)
y
# Out:
# array([0.18259636, 0.05319192, 0.71468535, 0.93615942, 0.76045113,
#        0.17370149, 0.88705894, 0.855959  , 0.57520636, 0.91934073,
#        0.7763341 , 0.62355684, 0.56786524, 0.04340975, 0.61828547,
#        0.40025049, 0.08172748, 0.56732087, 0.46661219, 0.63215766,
#        0.0769499 , 0.27075507, 0.47386845, 0.92582368, 0.61830904,
#        0.02653526, 0.48240941, 0.90103677, 0.45537578, 0.05606152,
#        0.58975983, 0.64595211, 0.15884835, 0.9205941 , 0.66017558,
#        0.06370526, 0.54811314, 0.67592717, 0.30863274, 0.66557722,
#        0.69635719, 0.67715306, 0.97186104, 0.97684156, 0.84580238,
#        0.44010959, 0.48295589, 0.67477958, 0.15788083, 0.06608395])

# %%
# scatter plot >> A scatter plot is a type of data visulisation that displays value for two variables as points on a cartesian plane.Each point represents the value of one variable corresponding to the value of other
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
# line plot
# whenever you want to deoict the relation between two variables in the form of trend
# mostly in x axis the date time column in there

x= [1,2,3,4,5] # assume x is no of day
y = [5,2,7,8,1] # y is price of stock

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [5, 2, 7, 8, 1]

# %%
plt.plot(x,y) # simple line chart

# %%
plt.plot(x,y)
plt.title("line chart to understand the syntax")
# Out:
# Text(0.5, 1.0, 'line chart to understand the syntax')

# %%
plt.plot(x,y)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
# Out:
# Text(0, 0.5, 'price as y points')

# %%
plt.plot(x,y)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y,color = "red")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y,color = "red", marker = "o")  # data point adrdress
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y,color = "red", marker = "o", linestyle = '--')   # style of line
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y,color = "red", marker = "o", linestyle = '--', linewidth = 4 )   # line thick
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y,color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)   # marker
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y,color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)   # marker
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y1 = [5,1,7,8,2]
y2 = [7,8,3,5,1]

plt.plot(x,y1, color = "red",marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label = "liney1")

# %%
x = [1,2,3,4,5]
y1 = [5,1,7,8,2]
y2 = [7,8,3,5,1]

plt.plot(x,y1, color = "red",marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label = "line y1 as tata motors")
plt.plot(x,y2, color = "b",marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label = "line y2 as tata power")

plt.title("Multiple lines in one plot")

plt.xlabel("Days")
plt.ylabel("stock price")
plt.legend()
plt.show()

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\pratap sarvaiya\appdata\local\programs\python\python311\lib\site-packages (2.0.1)
# DEPRECATION: Loading egg at c:\users\pratap sarvaiya\appdata\local\programs\python\python311\lib\site-packages\openpyxl-3.1.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
x = np.linspace(0,10,100)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x),'--')

# %%
plt.plot(x, np.sin(x),'-')

# %%
plt.plot(x, np.sin(x),'.-')

# %%
plt.plot(x, np.sin(x),':')

# %%
plt.figure()  # initialising a page to make plot
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
plt.figure()  # initialising a page to make plot
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)
plt.plot(x,np.tan(x))

plt.subplot(2,2,4)
plt.plot(x,np.sin(x+1))

plt.show()

# %%
plt.plot(x, np.sin(x), color = 'blue')

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.grid()
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)

plt.axis('equal')
plt.grid()
plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.show()

# %%
# histogram >> continuous numerical data 

data = np.random.randn(1000) # by default 10 bins are created
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000) # by default 10 bins are created
plt.hist(data, color = 'r', bins = 20)
plt.show()

# %%
#stacked histogram >> two histogram together

data1 = np.random.normal(0,1,5000)
data2 = np.random.normal(3,2,5000)

# %%
data1
# Out:
# array([2.37699532, 2.3694332 , 1.19054495, ..., 2.55561316, 0.35117552,
#        4.63293169])

# %%
data2
# Out:
# array([4.94959601, 4.09654117, 2.75015638, ..., 1.92931687, 4.15737951,
#        0.90823214])

# %%
plt.hist([data1,data2], bins = 20, color = ['r','b'], label = ['dict1','dict2'])
plt.xlabel("Values")
plt.ylabel("frequency")
plt.title("stacked histogram")
plt.show()

# %%
# scatterplot >> to understand the relationship between two features

x = np.random.rand(50)
y = np.random.rand(50)
x
# Out:
# array([0.28471531, 0.02569849, 0.49042729, 0.88752941, 0.93531656,
#        0.8542056 , 0.33651812, 0.93153409, 0.87714727, 0.72818388,
#        0.81317616, 0.83185174, 0.55629782, 0.29319235, 0.3332627 ,
#        0.39573338, 0.95427164, 0.00727629, 0.71408339, 0.3067939 ,
#        0.3477556 , 0.49351781, 0.47889235, 0.6971789 , 0.60484977,
#        0.88188869, 0.16718834, 0.17480258, 0.77911645, 0.00619029,
#        0.85516971, 0.71575909, 0.5235984 , 0.36263312, 0.02216858,
#        0.89322472, 0.03228275, 0.29320991, 0.78149869, 0.83881668,
#        0.03053853, 0.73318557, 0.723715  , 0.86805961, 0.66000605,
#        0.57157797, 0.1747049 , 0.93559266, 0.81311182, 0.98610425])

# %%
y
# Out:
# array([0.78252859, 0.45997036, 0.00486025, 0.25331917, 0.56932012,
#        0.43046998, 0.52784178, 0.31978267, 0.46712987, 0.17293742,
#        0.65016939, 0.51290999, 0.1162817 , 0.26781862, 0.16040824,
#        0.77947561, 0.98425473, 0.48056979, 0.39900479, 0.86441827,
#        0.23398065, 0.58959221, 0.3972081 , 0.60840122, 0.97172902,
#        0.51869451, 0.3892164 , 0.61254842, 0.63355283, 0.14710714,
#        0.90118803, 0.89358606, 0.92666349, 0.0475128 , 0.30549186,
#        0.74559294, 0.81266437, 0.49978152, 0.00939498, 0.94592602,
#        0.20243159, 0.77235462, 0.69811373, 0.72934048, 0.15046781,
#        0.34622073, 0.3652414 , 0.43377441, 0.58859281, 0.40618547])

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y, c = 'r', marker = 'X' )

# %%
# bar plot >> to see the distribution of categorical variables

x = ["a","b","c","d"]  # name of students
y = [4, 6, 1, 10]  # no of days present in the class

plt.bar(x, y, color = 'r')  # vertical plot
# Out:
# <BarContainer object of 4 artists>

# %%
x = ["a","b","c","d"]  # name of students
y = [4, 6, 1, 10]  # no of days present in the class

plt.barh(x, y, color = 'r')  # horizonatal plot
# Out:
# <BarContainer object of 4 artists>

# %%
# pie chart >> to understand the percent distribution of data

langs = ["c", 'python', "java"]
students = [20, 100, 40]

plt.pie(students, labels = langs)
plt.title("pie chart")
plt.show()

# %%
langs = ["c", 'python', "java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%")  # percentage in view
plt.title("pie chart")
plt.show()

# %%
# focus on one segment

explode = (0.0, 0.1,0.1)
langs = ["c", 'python', "java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%, explode = explode")  # percentage in view
plt.title("pie chart")
plt.show()

# %%
explode = (0.0, 0.1,0.1)
langs = ["c", 'python', "java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%, explode = explode, shadow = True")  # percentage in view
plt.title("pie chart")
plt.show()

# %%
# 3d plot >> 3 dimension plot
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c='r')

# %%
data = pd.read_csv("Bank_Churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
plt.scatter(x = data['Age'], y = data["Balance"])

# %%
data.plot.scatter(x = 'Age', y = 'Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'],color = 'r')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Balance'],color = 'r')
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
# Boxplot >> to check the distribution of data and outliers(extreme/abnormal values)
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
# Violin plot
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x16db7ed5c50>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x16db7ee2bd0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x16db796eed0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x16db7efcad0>}

# %% [raw]
# # Area plot >> variables changed over time
# An area plot, also called a stacked area plot, is a type of data visualization that shows how
# how various quantitaive factors have changed over time while highlifting how they all work together
# form the whole. It's particullarly good for illustrating how elements of a whole change over time or along a continous dimension.
# A layered representation of the data is produced in an area plot by layering many variables on top
# of one another. The comulative influence of all levels provides insight into the overall trend. Each
# layer represents a separate category or variable.
# To distinguish between categories, the space beneath each layer is frequently colored.

# %%
years = [2021,2016,2022,2023,2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]

plt.stackplot(years, category1,category2,category3,labels = ["category1","category2","category3",],
             colors = ["skyblue","lightgreen","orange"])
plt.xlabel("years")
plt.ylabel("Values")
plt.title("Area plot")
plt.legend()
plt.show()
