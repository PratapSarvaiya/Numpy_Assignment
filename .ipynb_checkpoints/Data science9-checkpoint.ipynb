# %%
# Pandas
2008, by Mckinney
# pandas is a data analysis and it works very well with structured/tabular data

# %%
import pandas as pd

# %%
df = pd.read_csv("services.csv")

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.head().T
# Out:
#                                                                          0  \
# id                                                                       1
# location_id                                                              1
# program_id                                                             NaN
# accepted_payments                                                      NaN
# alternate_name                                                         NaN
# application_process                             Walk in or apply by phone.
# audience                 Older adults age 55 or over, ethnic minorities...
# description              A walk-in center for older adults that provide...
# eligibility              Age 55 or over for most programs, age 60 or ov...
# email                                                                  NaN
# fees                     $2.50 suggested donation for lunch for age 60 ...
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.tail().T
# Out:
#                                                                         18  \
# id                                                                      19
# location_id                                                             19
# program_id                                                             NaN
# accepted_payments                                                      NaN
# alternate_name                                                         NaN
# application_process         Call for screening appointment (650-347-3648).
# audience                                                               NaN
# description              Provides free medical and dental care to those...
# eligibility                Low-income person without access to health care
# email                                                                  NaN
# fees                                                                 None.
# ...

# %%
df = pd.read_csv("services.csv",header =None)
df
# Out:
#     0            1           2                         3   \
# 0   id  location_id  program_id         accepted_payments
# 1    1            1         NaN                       NaN
# 2    2            2         NaN                       NaN
# 3    3            3         NaN                       NaN
# 4    4            4         NaN                       NaN
# 5    5            5         NaN                       NaN
# 6    6            6         NaN                       NaN
# 7    7            7         NaN                       NaN
# 8    8            8         NaN                       NaN
# 9    9            9         NaN                       NaN
# 10  10           10         NaN                       NaN
# 11  11           11         NaN                       NaN
# 12  12           12         NaN                       NaN
# 13  13           13         NaN                       NaN
# 14  14           14         NaN                       NaN
# ...

# %%
df = pd.read_csv("services.csv",usecols = ['program_id','application_process'])
df
# Out:
#     program_id                                application_process
# 0          NaN                         Walk in or apply by phone.
# 1          NaN                 Apply by phone for an appointment.
# 2          NaN        Phone for information (403-4300 Ext. 4322).
# 3          NaN                                    Apply by phone.
# 4          NaN                             Phone for information.
# 5          NaN  Walk in or apply by phone for membership appli...
# 6          NaN  Apply by phone or be referred by a doctor, soc...
# 7          NaN                                    Apply by phone.
# 8          NaN  Walk in. Proof of residency in California requ...
# 9          NaN  Walk in. Proof of California residency to rece...
# 10         NaN  Walk in. Proof of California residency require...
# 11         NaN  Walk in or apply by phone, email or webpage re...
# 12         NaN  Walk in. Proof of California residency require...
# ...

# %%
header = len(list(range(100,122)))

# %%
# whenever colma string appeares it should should be treated as null valyue
df = pd.read_csv("services.csv",names = header)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df = pd.read_csv("services.csv",names = header)
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.columns = ["a","b"]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.columns = ["a","b"]
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df['program_id']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# Name: program_id, dtype: float64

# %%
type(df['program_id'])
# Out:
# pandas.core.series.Series

# %%
df['application_process']
# Out:
# 0                            Walk in or apply by phone.
# 1                    Apply by phone for an appointment.
# 2           Phone for information (403-4300 Ext. 4322).
# 3                                       Apply by phone.
# 4                                Phone for information.
# 5     Walk in or apply by phone for membership appli...
# 6     Apply by phone or be referred by a doctor, soc...
# 7                                       Apply by phone.
# 8     Walk in. Proof of residency in California requ...
# 9     Walk in. Proof of California residency to rece...
# 10    Walk in. Proof of California residency require...
# 11    Walk in or apply by phone, email or webpage re...
# 12    Walk in. Proof of California residency require...
# 13    Call for appointment. Referral from human serv...
# 14            Walk in or through other agency referral.
# 15    Walk in. Written application, identification r...
# 16                                Call for information.
# ...

# %%
df.columns = header
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.columns = header
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     807 @final
#     808 def _set_axis(self, axis: AxisInt, labels: AnyArrayLike | list) -> None:
#     809     """
#     810     This is called from the cython code when we set the `index` attribute
# ...

# %%
l = [1,2,3,4]
s = pd.Series(l)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
d = {"name": "Ajay", "class":"pws"}
l = pd.Series(d)
l
# Out:
# name     Ajay
# class     pws
# dtype: object

# %%
b = pd.Series

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                a  \
# ...

# %%
df = pd.read_csv("services.csv")
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
# get the columns of the df and see which are the common column from the following list
# l = ["kakuda_ka_aatank","sarkate","website","name","desc"]

# %%
l = ["kakuda_ka_aatank","sarkate","website","name","desc"]
common_columns = list(set(df.columns).intersection(set(l)))
common_columns
# Out:
# ['website', 'name']

# %%
df.sample()
# Out:
#     id  location_id  program_id accepted_payments alternate_name  \
# 12  13           13         NaN               NaN            NaN
#
#                                   application_process audience  \
# 12  Walk in. Proof of California residency require...      NaN
#
#                                           description  \
# 12  Provides general reading materials, including ...
#
#                                         eligibility email  ...  \
# 12  Resident of California to obtain a library card   NaN  ...
#
#    interpretation_services                                           keywords  \
# 12                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
#
#    languages                   name required_documents     service_areas  \
# 12       NaN  Redwood Shores Branch                NaN  San Mateo County
#
#     status wait_time website taxonomy_ids
# 12  active  No wait.     NaN          NaN
#
# [1 rows x 22 columns]

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       23 non-null     int64
#  1   location_id              23 non-null     int64
#  2   program_id               0 non-null      float64
#  3   accepted_payments        1 non-null      object
#  4   alternate_name           1 non-null      object
#  5   application_process      23 non-null     object
#  6   audience                 14 non-null     object
#  7   description              23 non-null     object
#  8   eligibility              17 non-null     object
#  9   email                    1 non-null      object
#  10  fees                     21 non-null     object
#  11  funding_sources          21 non-null     object
#  12  interpretation_services  1 non-null      object
#  13  keywords                 21 non-null     object
# ...

# %%
# find all the columns which has datatype object
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.dtypes[df.dtypes != "object"].index
# Out:
# Index(['id', 'location_id', 'program_id'], dtype='object')

# %%
s = pd.Series([2,3,4],index = ["mojuka","ndbds","ram"])
s
# Out:
# mojuka    2
# ndbds     3
# ram       4
# dtype: int64

# %%
d = pd.DataFrame(s)
d
# Out:
#         0
# mojuka  2
# ndbds   3
# ram     4

# %%
d['new_column'] = "kakuda"

# %%
d
# Out:
#         0 new_column
# mojuka  2     kakuda
# ndbds   3     kakuda
# ram     4     kakuda

# %%
d['new_colums'] = [100,200,300]

# %%
d
# Out:
#         0 new_column  new_colums
# mojuka  2     kakuda         100
# ndbds   3     kakuda         200
# ram     4     kakuda         300

# %%
d.columns = ["amol","sukhver","somya"]
d
# Out:
#         amol sukhver  somya
# mojuka     2  kakuda    100
# ndbds      3  kakuda    200
# ram        4  kakuda    300

# %%
d.reset_index(drop=True)
# Out:
#    amol sukhver  somya
# 0     2  kakuda    100
# 1     3  kakuda    200
# 2     4  kakuda    300

# %%
df_subset = df[["name","status","languages"]]

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df_subset = df[["name","status","languages"]]
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
type(df_subset)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = pd.read_excel(")
df1

# %%
pd.read_csv("taxonomy.csv")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3[["Survived","Pclass"]]
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3
#
# [891 rows x 2 columns]

# %%
df3.Pclass.value_counts(normalize = True) * 100
# Out:
# Pclass
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: proportion, dtype: float64

# %%
df = pd.read_csv("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df = pd.read_csv("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
#       2 df
#
# ...

# %%
import requests
