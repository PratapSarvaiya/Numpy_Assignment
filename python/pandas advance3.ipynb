# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
"pw"+"skills"
# Out:
# 'pwskills'

# %%
df1 = df[["Name","Sex","Age"]][0:5]
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df2 = df[["Name","Sex","Age"]][5:10]
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                      Palsson, Master Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1,df2],axis=0)  # concatenate pandas dataframe/object along a particular axis
# by default axis 0, means the dataframes will be concatenated row wise(appears to be vertical)
# concattenation means keeping two dataframes either horizontally or vertically
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                      Palsson, Master Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                      Palsson, Master Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1,df2],axis=1)   #horizontal concatination
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                                NaN     NaN   NaN
# 6                                                NaN     NaN   NaN
# 7                                                NaN     NaN   NaN
# 8                                                NaN     NaN   NaN
# 9                                                NaN     NaN   NaN
#
#                                                 Name     Sex   Age
# 0                                                NaN     NaN   NaN
# 1                                                NaN     NaN   NaN
# ...

# %%
df2.reset_index(drop=True,inplace=True)
df2
# Out:
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                      Palsson, Master Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
inner merge >> merge based on common column is called inner merge(intersection)
left merge >> All the left elements of dataframe  A will be in the merge
right merge >> All the element of right dataframe B will be in the merge
Outer merge >> All the element of both the dataframe
cross >> every permutation of rows are there

# %%
# merge

df1 = pd.DataFrame({'key1':[1,2,4,5,6],
                     'key2':[4,5,6,7,8],
                     'key3':[3,4,5,6,6]})
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2 = pd.DataFrame({'key1':[1,2,45,6,67],
                     'key4':[56,5,6,7,8],
                     'key5':[3,56,5,6,6]})
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(df1,df2,how='inner')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
pd.merge(df1,df2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
pd.merge(df1,df2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
pd.merge(df1,df2,how='outer') # all the common element of the common column from both the dataframe
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(df1,df2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(df1,df2,how='left',left_on="key2",right_on="key4")
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       1     4     3     NaN   NaN   NaN
# 1       2     5     4     2.0   5.0  56.0
# 2       4     6     5    45.0   6.0   5.0
# 3       5     7     6     6.0   7.0   6.0
# 4       6     8     6    67.0   8.0   6.0

# %%
# join >> join works based on index/merge works on columns

# %%
df1 = pd.DataFrame({'key1':[1,2,4,5,6],
                     'key2':[4,5,6,7,8],
                     'key3':[3,4,5,6,6]},
                  index = ['a','b','c','d','e'])
df1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
df1 = pd.DataFrame(df1).set_index('a')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11460\1476324954.py in ?()
# ----> 1 df1 = pd.DataFrame(df1).set_index('a')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#    5873             frame = self
#
# KeyError: "None of ['a'] are in the columns"

# %%
df2 = pd.DataFrame({'key1':[1,2,45,6,67],
                     'key4':[56,5,6,7,8],
                     'key5':[3,56,5,6,6]},
                  index = ['a','b','h','i','j'])
df2
# Out:
#    key1  key4  key5
# a     1    56     3
# b     2     5    56
# h    45     6     5
# i     6     7     6
# j    67     8     6

# %%
df1.join(df12, how = "inner") # joins columns of anotther dataframe based on column index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df1.join(df12, how = "inner") # joins columns of anotther dataframe based on column index
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10412, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10402     if how == "cross":
#   10403         return merge(
#   10404             self,
#   10405             other,
#    (...)
#   10410             validate=validate,
#   10411         )
# > 10412     return merge(
#   10413         self,
#   10414         other,
#   10415         left_on=on,
#   10416         how=how,
#   10417         left_index=on is None,
#   10418         right_index=True,
#   10419         suffixes=(lsuffix, rsuffix),
#   10420         sort=sort,
#   10421         validate=validate,
#   10422     )
#   10423 else:
# ...

# %%
df1.join(df2, how = "left")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df1.join(df2, how = "left")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10412, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10402     if how == "cross":
#   10403         return merge(
#   10404             self,
#   10405             other,
#    (...)
#   10410             validate=validate,
#   10411         )
# > 10412     return merge(
#   10413         self,
#   10414         other,
#   10415         left_on=on,
#   10416         how=how,
#   10417         left_index=on is None,
#   10418         right_index=True,
#   10419         suffixes=(lsuffix, rsuffix),
#   10420         sort=sort,
#   10421         validate=validate,
#   10422     )
#   10423 else:
#   10424     if on is not None:
#
# ...

# %%
df1.join(df2, how = "inner")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df1.join(df2, how = "inner")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10412, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10402     if how == "cross":
#   10403         return merge(
#   10404             self,
#   10405             other,
#    (...)
#   10410             validate=validate,
#   10411         )
# > 10412     return merge(
#   10413         self,
#   10414         other,
#   10415         left_on=on,
#   10416         how=how,
#   10417         left_index=on is None,
#   10418         right_index=True,
#   10419         suffixes=(lsuffix, rsuffix),
#   10420         sort=sort,
#   10421         validate=validate,
#   10422     )
#   10423 else:
#   10424     if on is not None:
#
# ...

# %%
df1.join(df2, how = "right")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df1.join(df2, how = "right")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10412, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10402     if how == "cross":
#   10403         return merge(
#   10404             self,
#   10405             other,
#    (...)
#   10410             validate=validate,
#   10411         )
# > 10412     return merge(
#   10413         self,
#   10414         other,
#   10415         left_on=on,
#   10416         how=how,
#   10417         left_index=on is None,
#   10418         right_index=True,
#   10419         suffixes=(lsuffix, rsuffix),
#   10420         sort=sort,
#   10421         validate=validate,
#   10422     )
#   10423 else:
#   10424     if on is not None:
#
# ...

# %%
df1.join(df2, how = "outer")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df1.join(df2, how = "outer")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10412, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10402     if how == "cross":
#   10403         return merge(
#   10404             self,
#   10405             other,
#    (...)
#   10410             validate=validate,
#   10411         )
# > 10412     return merge(
#   10413         self,
#   10414         other,
#   10415         left_on=on,
#   10416         how=how,
#   10417         left_index=on is None,
#   10418         right_index=True,
#   10419         suffixes=(lsuffix, rsuffix),
#   10420         sort=sort,
#   10421         validate=validate,
#   10422     )
#   10423 else:
#   10424     if on is not None:
#
# ...

# %%
df1.join(df2, how = "cross")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df1.join(df2, how = "cross")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10403, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10401 if isinstance(other, DataFrame):
#   10402     if how == "cross":
# > 10403         return merge(
#   10404             self,
#   10405             other,
#   10406             how=how,
#   10407             on=on,
#   10408             suffixes=(lsuffix, rsuffix),
#   10409             sort=sort,
#   10410             validate=validate,
#   10411         )
#   10412     return merge(
#   10413         self,
#   10414         other,
#    (...)
#   10421         validate=validate,
#   10422     )
#   10423 else:
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# apply >> to apply a function on all the elements/values of a column
df['Fare'].apply(lambda x: x*90)
# Out:
# 0       652.500
# 1      6415.497
# 2       713.250
# 3      4779.000
# 4       724.500
#          ...
# 886    1170.000
# 887    2700.000
# 888    2110.500
# 889    2700.000
# 890     697.500
# Name: Fare, Length: 891, dtype: float64

# %%
df["Fare_inr"] = df['Fare'].apply(lambda x: x*90)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len("Ram")
# Out:
# 3

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                  Heikkinen, Miss Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                          Graham, Miss Margaret Edith
# 888              Johnston, Miss Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df["Name_len"] = df["Name"].apply(len)

# %%
df["Name_len"]
# Out:
# 0      23
# 1      51
# 2      21
# 3      44
# 4      24
#        ..
# 886    21
# 887    27
# 888    39
# 889    21
# 890    19
# Name: Name_len, Length: 891, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# user define function inside apply

def convert(x): 
    return x*90

# %%
df["Fare1"] = df["Fare"].apply(convert)

# %%
df["Fare1"]
# Out:
# 0       652.500
# 1      6415.497
# 2       713.250
# 3      4779.000
# 4       724.500
#          ...
# 886    1170.000
# 887    2700.000
# 888    2110.500
# 889    2700.000
# 890     697.500
# Name: Fare1, Length: 891, dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def create_flag(x):
    if x < 10:
        return "cheap"
    if x>=10 and x<20:
        return "medium"
    else:
        return "high"

# %%
create_flag(21)
# Out:
# 'high'

# %%
df["flag_fare"] = df['Fare'].apply(create_flag)

# %%
df["flag_fare"]
# Out:
# 0       cheap
# 1        high
# 2       cheap
# 3        high
# 4       cheap
#         ...
# 886    medium
# 887      high
# 888      high
# 889      high
# 890     cheap
# Name: flag_fare, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = {"a":[1,2,3,4],
       "b":[5,5,6,7],
       "c":["pw","skills","aj","cj"]}
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#    a  b       c
# 0  1  5      pw
# 1  2  5  skills
# 2  3  6      aj
# 3  4  7      cj

# %%
df1.set_index('c',inplace=True)

# %%
df1
# Out:
#         a  b
# c
# pw      1  5
# skills  2  5
# aj      3  6
# cj      4  7

# %%
df1.reset_index(drop=True,inplace=True)

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df1.reindex([1,2,3,0])  # makes new index for series and dataframe
# Out:
#    a  b
# 1  2  5
# 2  3  6
# 3  4  7
# 0  1  5

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
for i in df1.iterrows(): # iterate row wise
    print(i, ".......")
# Out:
# (0, a    1
# b    5
# Name: 0, dtype: int64) .......
# (1, a    2
# b    5
# Name: 1, dtype: int64) .......
# (2, a    3
# b    6
# Name: 2, dtype: int64) .......
# (3, a    4
# b    7
# Name: 3, dtype: int64) .......

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
for i in df1.items(): # iterate column wise
    print(i)
# Out:
# ('a', 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64)
# ('b', 0    5
# 1    5
# 2    6
# 3    7
# Name: b, dtype: int64)

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
def func_sum(x):   # column wise
    return x.sum()

# %%
df1.apply( func_sum,axis = 0)
# Out:
# a    10
# b    23
# dtype: int64

# %%
df1.apply( func_sum,axis = 1)
# Out:
# 0     6
# 1     7
# 2     9
# 3    11
# dtype: int64

# %%
df1.applymap(lambda x:x**2)
# Out:
# C:\Users\Pratap sarvaiya\AppData\Local\Temp\ipykernel_18744\231730792.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1.applymap(lambda x:x**2)
#     a   b
# 0   1  25
# 1   4  25
# 2   9  36
# 3  16  49

# %%
data = {"a":[100,200,13,4],
       "b":[5,5,6,7],
       "c":["pw","skills","aj","cj"]}
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#      a  b       c
# 0  100  5      pw
# 1  200  5  skills
# 2   13  6      aj
# 3    4  7      cj

# %%
df2.sort_values(by = 'a')  # Sort by the values along either axis.
# Out:
#      a  b       c
# 3    4  7      cj
# 2   13  6      aj
# 0  100  5      pw
# 1  200  5  skills
