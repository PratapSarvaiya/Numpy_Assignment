# %%
# python basic

# %%
#  Data type
# pratap 
# sarvaiya

# %%
help('keyword')
# Out:
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "Grammar/python.gram")
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/keyword.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This file is automatically generated; please don't muck it up!
#
#     To update the symbols in this file, 'cd' to the top directory of
#     the python source tree and run:
#
#         PYTHONPATH=Tools/peg_generator python3 -m pegen.keywordgen         Grammar/python.gram         Grammar/Tokens         Lib/keyword.py
#
#     Alternatively, you can run 'make regen-keyword'.
#
# FUNCTIONS
#     iskeyword = __contains__(...) method of builtins.frozenset instance
# ...

# %%
a=3
b=4
a+b
# Out:
# 7

# %%
name = input("enter your name")
name
# Out:
# enter your name 1
# '1'

# %%
type(name)
# Out:
# str

# %%
int(name)  # >> TYpe casting
# Out:
# 1

# %%
type(name)
# Out:
# str

# %%
float(name)
# Out:
# 1.0

# %%
complex(name)
# Out:
# (1+0j)

# %%
a = "pratap"
a
# Out:
# 'pratap'

# %%
a = " "
bool(a)
# Out:
# True

# %%
a = "Ajay"
type(a)
# Out:
# str

# %%
bool(a)
# Out:
# True

# %%
a=0
bool(a)
# Out:
# False

# %%
a=10.5
int(a)
# Out:
# 10

# %%
float(a)
# Out:
# 10.5

# %%
a=10
float(a)
# Out:
# 10.0

# %%
a="10k"

# %%
type(a)
# Out:
# str

# %%
a
# Out:
# '10k'

# %%
#a = 6


b = "Pratap"

# %%
b[0]
# Out:
# 'P'

# %%
b[1]
# Out:
# 'r'

# %%
b[1]="M"  # String is not immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 b[1]="M"
#
# TypeError: 'str' object does not support item assignment

# %%
# Mutable :- after creation is change
Immutable :- after creation is can't change

# %%
list = ["daal","bhat","chokha",1,2,"True",True]

# %%
list[0]
# Out:
# 'daal'

# %%
list[1]
# Out:
# 'bhat'

# %%
list[1]="bati"   # list is mutable

# %%
list
# Out:
# ['daal', 'bati', 'chokha', 1, 2, 'True', True]

# %%
list[3]=100

# %%
list
# Out:
# ['daal', 'bati', 'chokha', 100, 2, 'True', True]

# %%
a=3
b=4

# %%
# modulus operator
a%b
# Out:
# 3

# %%
5**3
# Out:
# 125

# %%
a+b
# Out:
# 7

# %%
a-b
# Out:
# -1

# %%
4/3
# Out:
# 1.3333333333333333

# %%
4 // 3  # neared whole no on lower side >> floor operator

# %%
2 == 2
# Out:
# True

# %%
4 == 2
# Out:
# False

# %%
2 != 2
# Out:
# False

# %%
# comparion op

# %%
10>10
# Out:
# False

# %%
10>=10
# Out:
# True

# %%
11<6
# Out:
# False

# %%
6<11
# Out:
# True

# %%
6 <= 6
# Out:
# True

# %%
6 >= 6
# Out:
# True

# %%
# logical operator

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
a = 10
a+5
# Out:
# 15

# %%
a = a+10

# %%
a+=5

# %%
a
# Out:
# 35

# %% [markdown]
#  a = 10
#  a*=2

# %%
a
# Out:
# 35

# %%
# Membership operator

# %%
a = "pratap"
"p" in a
# Out:
# True

# %%
"d" in a
# Out:
# False

# %%
# identity operator >> compare the memory location of two object

a = 2
b = 3
a is b
# Out:
# False

# %%
a = b
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
# Bitwise operator

10 & 10
# Out:
# 10

# %%
bin(10) # binary value of 10
# Out:
# '0b1010'

# %%
18 & 3 # this called 2
# Out:
# 2

# %%
bin(18) # this value is binary convert
# Out:
# '0b10010'

# %%
bin(2)  # this value is binary convert
# Out:
# '0b10'

# %%
5 | 3
# Out:
# 7

# %%
bin(7)
# Out:
# '0b111'

# %%
# negotion

~3
# Out:
# -4

# %%
~100
# Out:
# -101

# %%
# bitwise xor >> returns 1 when exactly operants/elements are 1 
any one always one other wise 0

5^3
# Out:
# 6

# %%
bin(5)
# Out:
# '0b101'

# %%
bin(3)
# Out:
# '0b11'

# %%
# shift 
#left shift :- put number of zeros on right
35 << 3
# Out:
# 280

# %%
bin(35)
# Out:
# '0b100011'

# %%
bin(3)
# Out:
# '0b11'

# %%
#100011000  left shift operator
bin(280)

# %%
bin(280)
# Out:
# '0b100011000'

# %%
# right shift >> remove the number of element in the binary
280 >> 3
# Out:
# 35

# %%
#0b100011
bin(280)
# Out:
# '0b100011000'

# %%
# order of precedence
2
